# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/diabetcsv.csv")
print(df)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 9 columns]

# %%
df.head(6)
# Out:
#    preg  plas  pres  skin  insu  mass   pedi  age            class
# 0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3     1    89    66    23    94  28.1  0.167   21  tested_negative
# 4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 5     5   116    74     0     0  25.6  0.201   30  tested_negative

# %%
df.tail(4)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
#droping a coloumn
af=df.drop("preg",axis=1)
print(af)
# Out:
#      plas  pres  skin  insu  mass   pedi  age            class
# 0     148    72    35     0  33.6  0.627   50  tested_positive
# 1      85    66    29     0  26.6  0.351   31  tested_negative
# 2     183    64     0     0  23.3  0.672   32  tested_positive
# 3      89    66    23    94  28.1  0.167   21  tested_negative
# 4     137    40    35   168  43.1  2.288   33  tested_positive
# ..    ...   ...   ...   ...   ...    ...  ...              ...
# 763   101    76    48   180  32.9  0.171   63  tested_negative
# 764   122    70    27     0  36.8  0.340   27  tested_negative
# 765   121    72    23   112  26.2  0.245   30  tested_negative
# 766   126    60     0     0  30.1  0.349   47  tested_positive
# 767    93    70    31     0  30.4  0.315   23  tested_negative
#
# [768 rows x 8 columns]

# %%
#drop the row
af=df.drop(3,axis=0)
print(af)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive
# 5       5   116    74     0     0  25.6  0.201   30  tested_negative
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative
#
# [767 rows x 9 columns]

# %%
#shuffling
af=df.sample(frac=1)
print(af)
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 524     3   125    58     0     0  31.6  0.151   24  tested_negative
# 368     3    81    86    16    66  27.5  0.306   22  tested_negative
# 521     3   124    80    33   130  33.2  0.305   26  tested_negative
# 121     6   111    64    39     0  34.2  0.260   24  tested_negative
# 301     2   144    58    33   135  31.6  0.422   25  tested_positive
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...
# 101     1   151    60     0     0  26.1  0.179   22  tested_negative
# 577     2   118    80     0     0  42.9  0.693   21  tested_positive
# 585     1    93    56    11     0  22.5  0.417   22  tested_negative
# 391     5   166    76     0     0  45.7  0.340   27  tested_positive
# 446     1   100    72    12    70  25.3  0.658   28  tested_negative
#
# [768 rows x 9 columns]

# %%
#Grouping
af=df.groupby('age')['class'].count()
print(af)
# Out:
# age
# 21    63
# 22    72
# 23    38
# 24    46
# 25    48
# 26    33
# 27    32
# 28    35
# 29    29
# 30    21
# 31    24
# 32    16
# 33    17
# 34    14
# 35    10
# 36    16
# 37    19
# 38    16
# 39    12
# 40    13
# 41    22
# 42    18
# 43    13
# 44     8
# 45    15
# 46    13
# 47     6
# 48     5
# 49     5
# 50     8
# 51     8
# 52     8
# 53     5
# 54     6
# 55     4
# 56     3
# 57     5
# 58     7
# 59     3
# 60     5
# 61     2
# 62     4
# 63     4
# 64     1
# 65     3
# 66     4
# 67     3
# 68     1
# 69     2
# 70     1
# 72     1
# 81     1
# Name: class, dtype: int64

# %%
# to a csv file(creating a csv file)
af.to_csv('/content/drive/MyDrive/agecount.csv')

# %%
#concat
af=pd.concat("preg"
print(af)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2261262557.py in <cell line: 0>()
#       1 #concat
# ----> 2 af=pd.concat("preg","age");print(af)
#
# TypeError: concat() takes 1 positional argument but 2 were given
